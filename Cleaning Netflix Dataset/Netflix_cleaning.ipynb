# %%
import pandas as pd
df = pd.read_csv('netflix1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df[['director_name','director_surname']] = df['director'].str.split(' ',n=1,expand=True)

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in director_name  \
# 0                                      Documentaries       Kirsten
# ...

# %%
df.drop(columns='director',inplace=True)

# %%
df.head()
# Out:
#   show_id     type                             title        country  \
# 0      s1    Movie              Dick Johnson Is Dead  United States
# 1      s3  TV Show                         Ganglands         France
# 2      s6  TV Show                     Midnight Mass  United States
# 3     s14    Movie  Confessions of an Invisible Girl         Brazil
# 4      s8    Movie                           Sankofa  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021          2020  PG-13    90 min
# 1  9/24/2021          2021  TV-MA  1 Season
# 2  9/24/2021          2021  TV-MA  1 Season
# 3  9/22/2021          2021  TV-PG    91 min
# 4  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in director_name  \
# 0                                      Documentaries       Kirsten
# 1  Crime TV Shows, International TV Shows, TV Act...        Julien
# 2                 TV Dramas, TV Horror, TV Mysteries          Mike
# ...

# %%
df['date_added'] = pd.to_datetime(df['date_added'], format='mixed', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   show_id           8790 non-null   object
#  1   type              8790 non-null   object
#  2   title             8790 non-null   object
#  3   country           8790 non-null   object
#  4   date_added        8790 non-null   datetime64[ns]
#  5   release_year      8790 non-null   int64
#  6   rating            8790 non-null   object
#  7   duration          8790 non-null   object
#  8   listed_in         8790 non-null   object
#  9   director_name     8790 non-null   object
#  10  director_surname  8725 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 755.5+ KB

# %%
df['Y'] = df['date_added'].dt.year
df['M'] = df['date_added'].dt.month
df['D'] = df['date_added'].dt.day

# %%
df.head()
# Out:
#   show_id     type                             title        country  \
# 0      s1    Movie              Dick Johnson Is Dead  United States
# 1      s3  TV Show                         Ganglands         France
# 2      s6  TV Show                     Midnight Mass  United States
# 3     s14    Movie  Confessions of an Invisible Girl         Brazil
# 4      s8    Movie                           Sankofa  United States
#
#   date_added  release_year rating  duration  \
# 0 2021-09-25          2020  PG-13    90 min
# 1 2021-09-24          2021  TV-MA  1 Season
# 2 2021-09-24          2021  TV-MA  1 Season
# 3 2021-09-22          2021  TV-PG    91 min
# 4 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in director_name  \
# 0                                      Documentaries       Kirsten
# 1  Crime TV Shows, International TV Shows, TV Act...        Julien
# 2                 TV Dramas, TV Horror, TV Mysteries          Mike
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   show_id           8790 non-null   object
#  1   type              8790 non-null   object
#  2   title             8790 non-null   object
#  3   country           8790 non-null   object
#  4   date_added        8790 non-null   datetime64[ns]
#  5   release_year      8790 non-null   int64
#  6   rating            8790 non-null   object
#  7   duration          8790 non-null   object
#  8   listed_in         8790 non-null   object
#  9   director_name     8790 non-null   object
#  10  director_surname  8725 non-null   object
#  11  Y                 8790 non-null   int32
#  12  M                 8790 non-null   int32
#  13  D                 8790 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(9)
# memory usage: 858.5+ KB

# %%
df.drop(columns='date_added',inplace=True)

# %%
df.head()
# Out:
#   show_id     type                             title        country  \
# 0      s1    Movie              Dick Johnson Is Dead  United States
# 1      s3  TV Show                         Ganglands         France
# 2      s6  TV Show                     Midnight Mass  United States
# 3     s14    Movie  Confessions of an Invisible Girl         Brazil
# 4      s8    Movie                           Sankofa  United States
#
#    release_year rating  duration  \
# 0          2020  PG-13    90 min
# 1          2021  TV-MA  1 Season
# 2          2021  TV-MA  1 Season
# 3          2021  TV-PG    91 min
# 4          1993  TV-MA   125 min
#
#                                            listed_in director_name  \
# 0                                      Documentaries       Kirsten
# 1  Crime TV Shows, International TV Shows, TV Act...        Julien
# 2                 TV Dramas, TV Horror, TV Mysteries          Mike
# 3                 Children & Family Movies, Comedies         Bruno
# ...

# %%
df[['Category 1','Category 2','Category 3']] = df['listed_in'].str.split(',',n=2,expand=True)

# %%
df
# Out:
#      show_id     type                             title        country  \
# 0         s1    Movie              Dick Johnson Is Dead  United States
# 1         s3  TV Show                         Ganglands         France
# 2         s6  TV Show                     Midnight Mass  United States
# 3        s14    Movie  Confessions of an Invisible Girl         Brazil
# 4         s8    Movie                           Sankofa  United States
# ...      ...      ...                               ...            ...
# 8785   s8797  TV Show                        Yunus Emre         Turkey
# 8786   s8798  TV Show                         Zak Storm  United States
# 8787   s8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788   s8784  TV Show                              Yoko       Pakistan
# 8789   s8786  TV Show                               YOM       Pakistan
#
#       release_year rating   duration  \
# 0             2020  PG-13     90 min
# ...

# %%
df.drop(columns='listed_in',inplace=True)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'country', 'release_year', 'rating',
#        'duration', 'director_name', 'director_surname', 'Y', 'M', 'D',
#        'Category 1', 'Category 2', 'Category 3'],
#       dtype='object')

# %%
cols = [['ID','Type','Title','Country','Release','Rating','Duration','Director_Name','Director_Surname','Y','M','D','C1','C2','C3']]

# %%
df.columns = cols

# %%
df.head()
# Out:
#     ID     Type                             Title        Country Release  \
# 0   s1    Movie              Dick Johnson Is Dead  United States    2020
# 1   s3  TV Show                         Ganglands         France    2021
# 2   s6  TV Show                     Midnight Mass  United States    2021
# 3  s14    Movie  Confessions of an Invisible Girl         Brazil    2021
# 4   s8    Movie                           Sankofa  United States    1993
#
#   Rating  Duration Director_Name Director_Surname     Y  M   D  \
# 0  PG-13    90 min       Kirsten          Johnson  2021  9  25
# 1  TV-MA  1 Season        Julien         Leclercq  2021  9  24
# 2  TV-MA  1 Season          Mike         Flanagan  2021  9  24
# 3  TV-PG    91 min         Bruno          Garotti  2021  9  22
# 4  TV-MA   125 min         Haile           Gerima  2021  9  24
#
#                          C1                       C2                      C3
# ...

# %%
df = df[['ID','Type','Title','Director_Name','Director_Surname','Country','Y','M','D','Release','Rating','Duration','C1','C2','C3']]

# %%
df.head()
# Out:
#     ID     Type                             Title Director_Name  \
# 0   s1    Movie              Dick Johnson Is Dead       Kirsten
# 1   s3  TV Show                         Ganglands        Julien
# 2   s6  TV Show                     Midnight Mass          Mike
# 3  s14    Movie  Confessions of an Invisible Girl         Bruno
# 4   s8    Movie                           Sankofa         Haile
#
#   Director_Surname        Country     Y  M   D Release Rating  Duration  \
# 0          Johnson  United States  2021  9  25    2020  PG-13    90 min
# 1         Leclercq         France  2021  9  24    2021  TV-MA  1 Season
# 2         Flanagan  United States  2021  9  24    2021  TV-MA  1 Season
# 3          Garotti         Brazil  2021  9  22    2021  TV-PG    91 min
# 4           Gerima  United States  2021  9  24    1993  TV-MA   125 min
#
#                          C1                       C2                      C3
# ...

# %%
df = df.fillna('')

# %%
df
# Out:
#          ID     Type                             Title Director_Name  \
# 0        s1    Movie              Dick Johnson Is Dead       Kirsten
# 1        s3  TV Show                         Ganglands        Julien
# 2        s6  TV Show                     Midnight Mass          Mike
# 3       s14    Movie  Confessions of an Invisible Girl         Bruno
# 4        s8    Movie                           Sankofa         Haile
# ...     ...      ...                               ...           ...
# 8785  s8797  TV Show                        Yunus Emre           Not
# 8786  s8798  TV Show                         Zak Storm           Not
# 8787  s8801  TV Show                Zindagi Gulzar Hai           Not
# 8788  s8784  TV Show                              Yoko           Not
# 8789  s8786  TV Show                               YOM           Not
#
#      Director_Surname        Country     Y   M   D Release Rating   Duration  \
# ...

# %%
import numpy as np

# %%
df['Director_Name'] = df['Director_Name'].replace('Not', np.nan)

# %%
df['Director_Surname'] = df['Director_Surname'].replace('Given', np.nan)

# %%
df
# Out:
#          ID     Type                             Title Director_Name  \
# 0        s1    Movie              Dick Johnson Is Dead       Kirsten
# 1        s3  TV Show                         Ganglands        Julien
# 2        s6  TV Show                     Midnight Mass          Mike
# 3       s14    Movie  Confessions of an Invisible Girl         Bruno
# 4        s8    Movie                           Sankofa         Haile
# ...     ...      ...                               ...           ...
# 8785  s8797  TV Show                        Yunus Emre           NaN
# 8786  s8798  TV Show                         Zak Storm           NaN
# 8787  s8801  TV Show                Zindagi Gulzar Hai           NaN
# 8788  s8784  TV Show                              Yoko           NaN
# 8789  s8786  TV Show                               YOM           NaN
#
#      Director_Surname        Country     Y   M   D Release Rating   Duration  \
# ...

# %%
df = df.fillna('')

# %%
df
# Out:
#          ID     Type                             Title Director_Name  \
# 0        s1    Movie              Dick Johnson Is Dead       Kirsten
# 1        s3  TV Show                         Ganglands        Julien
# 2        s6  TV Show                     Midnight Mass          Mike
# 3       s14    Movie  Confessions of an Invisible Girl         Bruno
# 4        s8    Movie                           Sankofa         Haile
# ...     ...      ...                               ...           ...
# 8785  s8797  TV Show                        Yunus Emre
# 8786  s8798  TV Show                         Zak Storm
# 8787  s8801  TV Show                Zindagi Gulzar Hai
# 8788  s8784  TV Show                              Yoko
# 8789  s8786  TV Show                               YOM
#
#      Director_Surname        Country     Y   M   D Release Rating   Duration  \
# 0             Johnson  United States  2021   9  25    2020  PG-13     90 min
# ...

# %%
df.to_csv('netflix_cleaned.csv',index=False)
